# %% [markdown]
# ### BERT model (Transformers library)
# > https://huggingface.co/abdelrahmanzied/bert-fake-news-classifier/tree/main

# %%
pip install xformers
# Out:
# ...
#                                               0.0/97.6 MB ? eta -:--:--
#                                               0.0/97.6 MB ? eta -:--:--
#                                              0.0/97.6 MB 330.3 kB/s eta 0:04:56
#                                              0.1/97.6 MB 939.4 kB/s eta 0:01:44
#                                               0.5/97.6 MB 2.8 MB/s eta 0:00:35
#                                               0.9/97.6 MB 4.3 MB/s eta 0:00:23
#                                               1.3/97.6 MB 5.0 MB/s eta 0:00:20
#                                               1.7/97.6 MB 5.7 MB/s eta 0:00:17
#                                               2.2/97.6 MB 6.3 MB/s eta 0:00:16
#      -                                        2.6/97.6 MB 6.4 MB/s eta 0:00:15
#      -                                        2.9/97.6 MB 6.5 MB/s eta 0:00:15
#      -                                        3.5/97.6 MB 6.9 MB/s eta 0:00:14
# ...

# %%
# Use a pipeline as a high-level helper
from transformers import pipeline

pipe = pipeline("text-classification", model="abdelrahmanzied/bert-fake-news-classifier")

# %%
# Load model directly
from transformers import AutoTokenizer, AutoModelForSequenceClassification

tokenizer = AutoTokenizer.from_pretrained("abdelrahmanzied/bert-fake-news-classifier")
model = AutoModelForSequenceClassification.from_pretrained("abdelrahmanzied/bert-fake-news-classifier")
